# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
import csv

data = []
data_labels = []

with open("./sarcasm_oneliners/data_test_sarcasm.csv") as f:
    csvreader = csv.reader(f)
    
    
    for row in csvreader:
        data.append(row[1])
        label = row[0]

        if label == '0':
            data_labels.append('non-sarcastic')
        else:
            data_labels.append('sarcastic')

# %%
vectorizer = CountVectorizer(analyzer = 'word', lowercase = False)

features = vectorizer.fit_transform(data)

features_nd = features.toarray()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    features_nd,
    data_labels,
    test_size=0.05,
    train_size=0.95,
    random_state=123
)

# %%
from sklearn.linear_model import LogisticRegression
log_model = LogisticRegression()

# %%
log_model = log_model.fit(X=X_train, y=y_train)

# %%
y_pred = log_model.predict(X_test)

# %%
import random
j = random.randint(0,len(X_test)-7)
for i in range(j,j+7):
    print(y_pred[0])
    ind = features_nd.tolist().index(X_test[i].tolist())
    print(data[ind].strip())
# Out:
# non-sarcastic
# I honestly wouldnt mind if DE decided to take a look at all weapons that were "X weapon but worse in every way" and give them some unique mechanic so that we dont just have like 20-30 useless weapons compared to the others.
# non-sarcastic
# he is the president... he already stopped Bobama from doing some ridiculous stuff.... but I'm sure he will do his fair share of ridiculous stuff too.
# non-sarcastic
# You could always pay it back in tithe or consider the thousands you've already given for maintenance of facilities.
# non-sarcastic
# Lol
# non-sarcastic
# Looks like a ban
# non-sarcastic
# Must be so hard to have a losing season
# non-sarcastic
# You forgot

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))
# Out:
# 0.5862068965517241
